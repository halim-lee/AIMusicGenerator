# %% [markdown]
# # Project File - APS360 Team 25
# Divided into the following section:
# #
# 1) Library imports
# 2) Data imports
# 3) Model architecture definition
# 4) Training function definition
# 5) Model training
# 6) Model testing

# %% [markdown]
# ## Library imports
# (Place all library imports here)

# %%
#KP - I just added the main ones from the labs.
import torch
import numpy as np

#import torchvision
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

import time # Tracking model training time.

#for Data importing
import mido
from mido import MidiFile, Message, MidiTrack, MetaMessage
import os
import random

# %%
#Set working directory if required:
os.chdir('D:\engsci\year 3\CLASS\APS360\Project') #Sets current working directory!

# %% [markdown]
# ## Data imports
# #### MIDI reading functions

# %%
def CountTracks(directory):          #Count files and tracks in folder
    trackCount = 0
    fileCount = 0
    for file in os.listdir(directory):
        if file.endswith(".midi"):
            fileCount += 1
            midiDir = MidiFile(directory+"/"+file)
            for track in midiDir.tracks:
                trackCount += 1
    print(fileCount+" files")
    print(trackCount+" tracks")

    
def PrintMessages(mid):                # print midi messages
    for i, track in enumerate(mid.tracks):
        print('Track {}: {}'.format(i, track.name))
        for msg in track:
            print(msg)

            
def PrintSomeMessages(mid):             #print first 200 midi messages
    track = mid.tracks[1]
    for i,msg in enumerate(track):
        if i < 200:
            print(msg)
            
def PrintMetaMessages(mid):             #print fmeta messages
    track = mid.tracks[0]
    for i,msg in enumerate(track):
        print(msg)

def cleanupMessages(mid):              #removes non-note messages by force
    track = mid.tracks[1]
    track2 = []
    for msg in track:
        if msg.type == "note_on":
            track2.append(msg)
    mid.tracks[1] = track2

# %% [markdown]
# #### MIDI to Numpy code

# %%
def Midi2NumpyNoSustain(mid):                                #converts to numpy array removing non-note messages
    track = mid.tracks[1]                           #0th track only contains meta-messages, all notes on 1st track
    notes = np.empty([0,4])
    time = 0
    for msg in track:
        if msg.type == "note_on":                   # only count "note" messages - other inputs i.e. foot pedals are ignored
            notes = np.append(notes,np.array([[msg.note, msg.velocity, msg.time + time, 0]]),axis=0)         # (note, velocity, time, sustain)
            time = 0
        else:
            time += msg.time                        #adjust time when removing other messages
    return notes


def NumpyGetSustain(note):
    notes = np.copy(note)
    for i, msg in enumerate(notes):
        if msg[1] > 0:                            # if velocity is not 0
            j = 1
            sustain = 0
            while msg[0] != notes[i+j][0]:        # while note values are different
                sustain += notes[i+j][2]
                j += 1                            #search for next message with same note i.e. message telling that note was released
            notes[i,3] = sustain + notes[i+j][2]
    time = 0
    for i, msg in enumerate(notes):
        if msg[1] > 0:
            notes[i,2] += time
            time = 0
        else:
            time += msg[2]                        #adjust time
    notes = notes[notes[:,1] > 0]                 #filter for notes with positive velocities (note presses)
    return notes

def NumpyNormalize(note):                         #normalize all values to 0-1
    notes = np.copy(note)
    for i, msg in enumerate(notes):
        notes[i,0] = msg[0]/128
        notes[i,1] = msg[1]/128
        notes[i,2] = msg[2]/40000
        notes[i,3] = msg[3]/40000    
    return notes

def Midi2Numpy(path): # full midi to numpy conversion
    mid = MidiFile(path)
    notes = Midi2NumpyNoSustain(mid)
    cleanNotes = NumpyGetSustain(notes)
    normNotes = NumpyNormalize(cleanNotes)
    return normNotes

# %% [markdown]
# #### Numpy to MIDI code

# %%
def NumpyDenormalize(note): # interpret all values from 0-1 to normal values
    notes = np.copy(note)
    for i, msg in enumerate(notes):
        notes[i,0] = msg[0]*128
        notes[i,1] = msg[1]*128
        notes[i,2] = msg[2]*40000
        notes[i,3] = msg[3]*40000
    return notes.astype(int)

def NumpySequence(notes): # put all ntoes into a "timeline" i.e.: time values of [10, 20, 10, 30] become [10, 30, 40, 70]
    sequenced = np.copy(notes)                      # this allows us to easily add vel=0 notes in any order since we can later sort them by time
    for i, msg in enumerate(sequenced):
        if i > 0:
            sequenced[i,2] += sequenced[i-1,2]
    return sequenced

def NumpyAddOffNotes(sequenced): # add vel=0 notes from sustain into sequenced timeline
    withOff = np.copy(sequenced)
    for msg in sequenced:
        offNote = np.array([[msg[0], 0, msg[2] + msg[3], 0]])
        withOff = np.append(withOff, offNote, axis=0)
    #withOff = np.sort(withOff,axis=0)
    withOff = withOff[withOff[:,2].argsort()] # sort by time
    return withOff

def NumpyUnsequence(notes): # revert time value to "time since last message"
    unsequenced = np.copy(notes)
    for i, msg in reversed(list(enumerate(unsequenced))):
        unsequenced[i,3] = 0
        if i > 0:
            unsequenced[i,2] -= unsequenced[i-1,2]
    return unsequenced

def Numpy2MidiDirect(array):    #make MIDI object from numpy
    #Start with initializing a new Mido Track:
    mid = MidiFile()
    track0 = MidiTrack()
    track1 = MidiTrack()
    
    track0.append(MetaMessage('set_tempo', tempo=500000, time=0)) #MetaMessages not necessary but are present in used files
    track0.append(MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0))
    track0.append(MetaMessage('end_of_track', time=1))
    
    track1.append(Message('program_change', channel=0, program=0, time=0))
    
    for i,note in enumerate(array):         # Get the index and the note. Array must be int array
        j = 1
        track1.append(Message('note_on',note = array[i,0], velocity = array[i,1],time = array[i,2])) # Add the note to the track.

    mid.tracks.append(track0)
    mid.tracks.append(track1)
    return mid

def Numpy2Midi(notes, name): # full numpy to midi conversion, saving result to [name].midi
    denorm = NumpyDenormalize(notes)
    seq = NumpySequence(denorm)
    off = NumpyAddOffNotes(seq)
    unseq = NumpyUnsequence(off)
    mid = Numpy2MidiDirect(unseq)
    mid.save(name + ".midi")

# %% [markdown]
# #### Generating tensor dataset from CSVs

# %%
def Numpy2Dataset(notes,num=5,skip=10): # make list of sumpy arrays #Playing with window sized (num)
    samples = []
    i = 0
    while i+num <= len(notes):
        samples.append(notes[i:i+num])
        i += skip
    return samples

def SampleAllNumpy(dataPath): # generate samples from all saved CSVs
    allSamples = []

    for i,f in enumerate(os.listdir(dataPath)):
        
        
        if i % 1280 == 0:
            print(i)
            notes = np.genfromtxt(dataPath+f, delimiter=',') #Moved down... 
            allSamples += Numpy2Dataset(notes) #Moved down into if statement...
    
    return allSamples

def SaveSamplesTensor(samples, outputPath): # save tensor
    tens = torch.Tensor(samples)
    torch.save(samples, outputPath+"Notes_Dataset_overfit.pt")
    return tens   

def SaveAllSamples(dataPath, outputPath): # save dataset tensor
    samples = SampleAllNumpy(dataPath)
    SaveSamplesTensor(samples, outputPath)
    print('done')

# %% [markdown]
# #### Bulk data conversion code - COMMENT OUT IF NOT IN USE!!!

# %%
# SaveAllSamples("D:/engsci/year 3/CLASS/APS360/Project/data/numpy_files/","D:/engsci/year 3/CLASS/APS360/Project/data/") #save all into tensor

# %% [markdown]
# ## Baseline Model Code
# #### getting available notes

# %%
def GetAllNotesMajor(root):# Get all used notes in major scale of root=root
    notes = []
    intervals = [2,2,1,2,2,2,1]
    
    while root > 24: #bring down to lowest used octave
        root -= 12
    
    n = root
    notes.append(n)
    while n < 84: #up to higherst used note
        for i in intervals:
            n += i
            notes.append(n)   
    return notes    


def GetRangeMajor(notes, low, high): # Get all notes within range
    lowIndex = notes.index(low)
    highIndex = notes.index(high)
    
    return notes[lowIndex:highIndex+1]

# %% [markdown]
# #### Piece Class
# ##### represents whole output from all 4 voices

# %%
class Piece: # Entire baseline model compostion - composed of 4 voices soprano, alto, tenor, bass (SATB)
    def __init__(self, barNum=16, root=60):# 16 bars in C major
        self.root = root # root note
        self.allNotes = GetAllNotesMajor(self.root) # all notes on major scale
        self.barNum = barNum # number of bars
        
        self.soprano = Voice(self.allNotes,60,84,speed=8) # SATB
        self.alto = Voice(self.allNotes,48,72)
        self.tenor = Voice(self.allNotes,36,60)
        self.bass = Voice(self.allNotes,24,48)
          
        self.notes = np.empty([0,4]) #notes output
        
        self.pieceChords = [] # chords
        
        self.chords = np.array([ # common classical C major chords
            [ 0,  4,  7,  0],# I
            [ 2,  5,  9,  2],# ii
            [ 4,  7, 11,  4],# iii
            [ 5,  9, 0,  5],# IV
            [ 7, 11, 2,  7],# V
            [ 9, 0, 4,  9],# vi
            [11, 2, 5, 11],# vii dim
            [ 2,  5,  9, 0],# ii7
            [ 5,  9, 0, 4],# IVmaj7
            [ 7, 11, 2, 5],# V7
            [11, 2, 5, 9]])# vii7 half-dim
        
    def GenerateSoprano(self): # Generate soprano line
        self.soprano.GenerateLine(self.soprano.speed*self.barNum)
        
    def GenerateAlto(self): # Generate alto line from chords
        self.alto.GenerateChordLine(self.pieceChords)
        
    def GenerateTenor(self): # see alto
        self.tenor.GenerateChordLine(self.pieceChords)
        
    def GenerateBass(self): # see alto
        self.bass.GenerateChordLine(self.pieceChords)
        
        
    
    def ChooseChord(self, sopNote): # Choose a fitting chord for soprano note
        while sopNote >= 12:
            sopNote -= 12
        
        goodChords = np.empty([0,4])
        
        for chord in self.chords:
            if (chord==sopNote).sum() > 0:
                goodChords = np.append(goodChords,[chord],axis=0)
        
        chosenChord = goodChords[random.randint(0,len(goodChords)-1)]
        chosenChord = np.sort(np.unique(chosenChord))
        
        i = 12
        chordNotes = chosenChord
        while i < 120:
            chordNotes = np.append(chordNotes, chosenChord+i)
            i += 12
        
        return(chordNotes)
    
    def GetChords(self): # select all chords in piece
        for i, note in enumerate(self.soprano.notes):
            if i % 2 == 0:
                sopNote = note[0]
                chord = self.ChooseChord(sopNote)
                self.pieceChords.append(chord)
                
    def GenerateLines(self): # Generate all SATB lines and joins them - entire baseline model
        self.GenerateSoprano()
        self.GetChords()
        self.GenerateAlto()
        self.GenerateTenor()
        self.GenerateBass()
        self.joinLines()
        
        self.notes = self.notes.astype(int)
        self.OffsetTime(20)
        
        return self.notes
        
    def InsertLine(self, starting, inserted, startIndex, skipIndex): # join 2 lines
        base = np.copy(starting)
        ins = np.copy(inserted)
        
        for i,note in enumerate(ins):
            base = np.insert(base, (i*skipIndex)+startIndex, [note], axis=0)
            
        return base
        
    def joinLines(self): # join all SATB lines
        #self.notes = np.copy(self.soprano)
        self.notes = self.InsertLine(self.soprano.notes, self.alto.notes, 1, 3)
        self.notes = self.InsertLine(self.notes, self.tenor.notes, 2, 4)
        self.notes = self.InsertLine(self.notes, self.bass.notes, 3, 5)
        
    def OffsetTime(self, maxChange): # adds random time offsets to make output more organic
        for note in self.notes:
            note[2] += random.randint(0,maxChange)

# %% [markdown]
# #### Voice class
# ##### Represents individual voices

# %%
class Voice: # individual voices
    def __init__(self, allNotes, lowNote, highNote, jump=3, speed=4, time=4096, velocity=64):
        self.range = GetRangeMajor(allNotes,lowNote,highNote) #available ntoes
        self.jump = jump #maximum pitch interval between notes
        self.speed = speed #note length i.e. 4 for quarter, 8 for eighth etc.
        self.time = time #song speed
        self.velocity = velocity #note volume
        self.notes = np.empty([0,4]) #notes output
        self.lowNote = lowNote # lowest note
        self.highNote = highNote # highest note
        self.allNotes = allNotes # all notes in scale
            
        self.duration = self.time / self.speed # time between notes
        
        
    def RandomStartNote(self): # Generate Random first note (for soprano)
        note = random.choice(self.range)
        self.notes = np.append(self.notes,np.array([[note, self.velocity, 0, self.duration]]),axis=0)
        
        
    def RandomJump(self): # Generate Random next note (for soprano)
        lastNote = self.notes[len(self.notes)-1][0] # find last played note
        lastIndex = self.range.index(lastNote)
        
        newIndex = -1
        while newIndex < 0 or newIndex >= len(self.range): # stay in range
            newIndex = lastIndex + random.randint(-self.jump,self.jump)
            
        newNote = self.range[newIndex]
        self.notes = np.append(self.notes,np.array([[newNote, self.velocity, self.duration, self.duration]]),axis=0)
        
        
    def GenerateLine(self, length): # Generate random line (for soprano)
        self.RandomStartNote()
        
        for n in range(length-1):
            self.RandomJump()
            
            
    def clearNotes(self):
        self.notes = np.empty([0,4])
        
    def GetChordNotes(self, chordNotes): # Get useful notes from all chord notes
        chordNotes = chordNotes[chordNotes >= self.lowNote]
        chordNotes = chordNotes[chordNotes <= self.highNote]
        return chordNotes
    
    def ChooseStartChordNote(self, chordNotes): # Choose Random note in chord
        note = random.choice(chordNotes)
        self.notes = np.append(self.notes,np.array([[note, self.velocity, 0, self.duration]]),axis=0)
        
    def ChooseChordNote(self,chordNotes): # Choose suitable next note in chord
        lastNote = self.notes[len(self.notes)-1][0] # find last played note
        
        chordNotes = chordNotes[chordNotes >= lastNote - (self.jump*2)]
        chordNotes = chordNotes[chordNotes <= lastNote + (self.jump*2)]
        newNote = random.choice(chordNotes)
        
        self.notes = np.append(self.notes,np.array([[newNote, self.velocity, 0, self.duration]]),axis=0)
        
    def GenerateChordLine(self, chords): # Generate A/T/B lines
        
        firstChord = self.GetChordNotes(chords[0])
        self.ChooseStartChordNote(firstChord)
        
        for c in chords[1:]:
            chord = self.GetChordNotes(c)
            self.ChooseChordNote(chord)

# %% [markdown]
# ## Model architecture definition

# %% [markdown]
# Set the hyperparameters below:

# %%
#For LSTM: https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html#torch.nn.LSTM 
n1 = 1 #Number of input features
nh1 = 1 #Number of features in the hidden state h
nl1 = 1 #Number of layers in each LSTM calling (more than 1 stacks them with same number of hidden features).
dropout1 = 0 #Percentage dropout of each layer. I believe 0-->1 range.

n2 = 1 #Number of input features
nh2 = 1 #Number of features in the hidden state h
nl2 = 1 #Number of layers in each LSTM calling (more than 1 stacks them with same number of hidden features).
dropout2 = 0 #Percentage dropout of each layer. I believe 0-->1 range.

# %%
# torch.manual_seed(1000) #Set the manual seed so that we get reproducible results.

# #Define the RNNMusicGenerator model below:
# class RNNMusicGenerator(nn.Module): 
#     def __init__(self):
#         super(RNNMusicGenerator, self).__init__()
#         self.name = "MusicGen"
#         self.LSTM1 = nn.LSTM(input_size = n1, hidden_size = nh1,num_layers = nl1, batch_first = True,dropout = dropout1)
#         #^^Expects data as: (batch_size,sequence,features)
#         self.LSTM2 = nn.LSTM(input_size = n, hidden_size = nh,num_layers = nl, batch_first = True,dropout = dropout)
#         #unsure of the output dimensions still...
#     def forward(self, x):
#         x = (F.relu(self.LSTM1(x)))
#         x = self.LSTM2(x) #No activation function on second layer for now...
#         return x
    
# print('Model class created succesfully')

# %% [markdown]
# # Regression based model

# %%
class RNNMusicGenerator(nn.Module): #GRU based
    def __init__(self, input_size = 4, hidden_size = 64):
        super(RNNMusicGenerator, self).__init__()
        self.name = "LSTM_Reg_ws20_simple_model"
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.rnn = nn.LSTM(self.input_size, self.hidden_size, batch_first = True)
#         self.rnn1 = nn.LSTM(self.hidden_size, self.hidden_size, batch_first = True)
        self.rnn1 = nn.LSTM(self.hidden_size, self.hidden_size, batch_first = True)
        #^^Expects data as: (batch_size,sequence,features)
        self.linear1 = nn.Linear(self.hidden_size, 32)
        self.linear2 = nn.Linear(32,16)
        self.linear = nn.Linear(self.hidden_size, 4) #Regression problem.

    def forward(self, x):
        h0 = torch.zeros(1,x.size(0),self.hidden_size)
        c0 = torch.zeros(1,x.size(0),self.hidden_size)
        out,(h0,c0) = self.rnn(x,(h0,c0))
        out = F.relu(out)
#         h1 = torch.zeros(1,x.size(0),self.input_size)
#         c1 = torch.zeros(1,x.size(0),self.input_size)
#         out,(h0,c0) = self.rnn1(out,(h0,c0))
#         out = F.relu(out)
#         out,(h0,c0) = self.rnn1(out,(h0,c0))
#         print(output.shape)
#         out = F.relu(out)
#         output,_ = self.RNN2(output,(None,None)) #No activation function on second layer for now...
#         print(hidden)    
#         out = self.linear1(out[:,-1,:])
#         out = self.linear(out) #Takes the last one...
#         out = F.relu(out)
#         out = self.linear2(out)
#         out = F.relu(out)
        pred = self.linear(out[:,-1,:]) #Takes the last one...
        return pred, True
    
print('Model class created succesfully')
# Out:
# Model class created succesfully

# %% [markdown]
# ## Training function

# %%
#To help us save the model easier...
def get_model_name(name, batch_size, learning_rate, epoch):
    """ Generate a name for the model consisting of all the hyperparameter values

    Args:
        config: Configuration object containing the hyperparameters
    Returns:
        path: A string with the hyperparameter name and value concatenated
    """
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

# %%
def train_network(model,data, num_epochs=20, batch_size=1, learning_rate=1e-5):
    torch.manual_seed(1000) #Fixed. Make sure we use this throughout...
    criterion = nn.MSELoss() # mean square error loss. Compares reconstruction errors entry by entry. For regression.
    optimizer = torch.optim.Adam(model.parameters(),
                                 lr=learning_rate, 
                                 weight_decay=1e-5) # <-- Sometimes Adam converges faster than SGD
    train_loader = torch.utils.data.DataLoader(data, 
                                               batch_size=batch_size, 
                                               shuffle=True) #Using train_loader wasn't working and was uneeded.
    
    iters, losses, train_acc, val_acc, epochs = [], [], [], [], []
    
    n = 0 # the number of iterations
    start_time=time.time() #Start of training.
    outputs = []
    
    for epoch in range(num_epochs):
        for sample in data:
            sample = sample.unsqueeze(0) #RNN structure needs (batch_first...)
#             print(sample)
#             print(type(sample))
            excerpt = sample[0:1,:-1] # Extracts all but the last row (model will predict last note)
#             print(excerpt.shape)
            true_note = sample[0:1,-1] # Extracts the last row (what we want it to predict).
#             print(true_note)
#             print('true_note.shape: ',true_note.shape)
            pred_note,_ = model(excerpt) # Collects next note prediction. #Throw out the hidden layer. Only from -1->1... Why?
            # Round to nearest integers
#             pred_note = pred_note.type(torch.int)
            
#             print(type(pred_note))
#             print('pred_note.shape: ',pred_note.shape)
#             print(pred_note.reshape(-1,4).shape, ' ',true_note.reshape(-1).shape)
            loss = criterion(pred_note, true_note.reshape(-1)) #pred_note gets spit out as (batch,1,4)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad() # Clean up, clean up, everybody, everywhere...

                
            iters.append(n)
            losses.append(float(loss)/batch_size)             # compute *average* loss
            if not n%10:
                
                print('Iteration:{}, Loss:{:.4f}'.format(n, float(loss)))
            
            n += 1
        train_acc.append(get_accuracy(model, data)) # compute training accuracy
        epochs.append(epoch)
        print('Epoch:{}, Loss:{:.4f}, train_acc:{}'.format(epoch+1, float(loss),train_acc[epoch]))
        print('predicted note: ',pred_note)
        outputs.append((epoch, true_note, pred_note),)
      #Checkpoint the model every epoch
        model_path = get_model_name(model.name, batch_size, learning_rate, epoch) #Returns the model name for 
      #the save file.
        print('model_path: ',model_path)
        torch.save(model.state_dict(), model_path) #Saves the current model with the weights.
        print('model checkpointed')
    end_time= time.time()
    
    
      # plotting
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(epochs, train_acc, label="Train")
#     plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
#     print("Final Validation Accuracy: {}".format(val_acc[-1]))
    return True

# %%
def get_accuracy(model, data): #Accuracy on note selection...
    correct = 0
    total = 0
    data_loader = torch.utils.data.DataLoader(data, 
                                               batch_size=1, 
                                               shuffle=True)
    for sample in data:
        sample = sample.unsqueeze(0)
#         print(sample)
        excerpt = sample[0:1,:-1] # Extracts all but the last row (model will predict last note)
#             print(excerpt.shape)
        true_note = sample[0:1,-1] # Extracts the last row (what we want it to predict).
#             print(true_note)
#             print('true_note.shape: ',true_note.shape)
        pred_note,_ = model(excerpt) # Collects next note prediction. #Throw out the hidden layer. Only from -1->1... Why?
#         print(pred_note[0][0])
        #select index with maximum prediction score
        if abs(pred_note[0][0] - true_note[0][0]) < 1e-2: #Won't ever be 'perfect', but can set a threshold difference...
#             print('correct predictions!')
            print(pred_note[0][0])
            print(true_note[0][0])
            correct += 1
        total += 1
    return correct / total

# %% [markdown]
# ## Model Training

# %%
# #Trying to overfit to small training set...
# model = RNNMusicGenerator()
# data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_10_overfit.pt') #Will take a moment to load...
# #Notes_Dataset_overfit: Has window sizes of 5... May be too small. Will try with 10
# #the 'r' in the front is a requirement...
# data = torch.tensor(data).float() #This line prevents an error.

# print(len(data))

# train_network(model,data,batch_size = 128,num_epochs = 200,learning_rate = 1e-3) #Need very small learning_rate to avoid model learning standard note.
# #Too large of a learning_rate value and it converges to average value. Too small and it converges to smaller one.

# %%
# #Trying to overfit to small training set...
# #Larger window size is better
# model = RNNMusicGenerator()
# data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_50_overfit.pt') #Will take a moment to load...
# #Notes_Dataset_overfit: Has window sizes of 5... May be too small. Will try with 10
# #the 'r' in the front is a requirement...
# data = torch.tensor(data).float() #This line prevents an error.

# print(len(data))

# train_network(model,data,batch_size = 128,num_epochs = 200,learning_rate = 1e-3) #Need very small learning_rate to avoid model learning standard note.
# #Too large of a learning_rate value and it converges to average value. Too small and it converges to smaller one.

# %%
# #Trying to overfit to small training set...
# #Larger window size is better
# model = RNNMusicGenerator()
# data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_50_overfit_medium.pt') #Will take a moment to load...
# #Notes_Dataset_overfit: Has window sizes of 5... May be too small. Will try with 10
# #the 'r' in the front is a requirement...
# data = torch.tensor(data).float() #This line prevents an error.

# print(len(data))

# train_network(model,data,batch_size = 128,num_epochs = 200,learning_rate = 1e-3) #Need very small learning_rate to avoid model learning standard note.
# #Too large of a learning_rate value and it converges to average value. Too small and it converges to smaller one.

# %%
# # Trying to overfit to small training set...
# #Larger window size is better
# model = RNNMusicGenerator()
# data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_50_overfit.pt') #Will take a moment to load...
# #Notes_Dataset_overfit: Has window sizes of 5... May be too small. Will try with 10
# #the 'r' in the front is a requirement...
# data = torch.tensor(data).float() #This line prevents an error.

# print(len(data))

# train_network(model,data,batch_size = 128,num_epochs = 300,learning_rate = 1e-4) #Need very small learning_rate to avoid model learning standard note.
# #Too large of a learning_rate value and it converges to average value. Too small and it converges to smaller one.

# %%
# Trying to overfit to small training set...
# Changing the window size...
#Larger window size is better
model = RNNMusicGenerator(hidden_size = 32)
data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_20_overfit_large.pt') #Will take a moment to load...
#Notes_Dataset_overfit: Has window sizes of 5... May be too small. Will try with 10
#the 'r' in the front is a requirement...
data = torch.tensor(data).float() #This line prevents an error.

print(len(data))

train_network(model,data,batch_size = 128,num_epochs = 20,learning_rate = 1e-3) #Need very small learning_rate to avoid model learning standard note.
#Too large of a learning_rate value and it converges to average value. Too small and it converges to smaller one.
# Out:
# 9136
# Iteration:0, Loss:0.0676
# Iteration:10, Loss:0.0828
# Iteration:20, Loss:0.1124
# Iteration:30, Loss:0.0188
# Iteration:40, Loss:0.0047
# Iteration:50, Loss:0.0024
# Iteration:60, Loss:0.0045
# Iteration:70, Loss:0.0085
# Iteration:80, Loss:0.0047
# Iteration:90, Loss:0.0205
# Iteration:100, Loss:0.0003
# Iteration:110, Loss:0.0007
# Iteration:120, Loss:0.0102
# Iteration:130, Loss:0.0045
# Iteration:140, Loss:0.0030
# Iteration:150, Loss:0.0184
# Iteration:160, Loss:0.0014
# Iteration:170, Loss:0.0013
# Iteration:180, Loss:0.0099
# Iteration:190, Loss:0.0086
# Iteration:200, Loss:0.0058
# Iteration:210, Loss:0.0076
# Iteration:220, Loss:0.0052
# Iteration:230, Loss:0.0047
# Iteration:240, Loss:0.0109
# Iteration:250, Loss:0.0023
# Iteration:260, Loss:0.0060
# Iteration:270, Loss:0.0055
# Iteration:280, Loss:0.0013
# Iteration:290, Loss:0.0260
# Iteration:300, Loss:0.0159
# Iteration:310, Loss:0.0037
# Iteration:320, Loss:0.0142
# Iteration:330, Loss:0.0016
# Iteration:340, Loss:0.0111
# Iteration:350, Loss:0.0062
# Iteration:360, Loss:0.0208
# Iteration:370, Loss:0.0016
# Iteration:380, Loss:0.0006
# Iteration:390, Loss:0.0106
# Iteration:400, Loss:0.0006
# Iteration:410, Loss:0.0060
# Iteration:420, Loss:0.0248
# Iteration:430, Loss:0.0072
# Iteration:440, Loss:0.0029
# Iteration:450, Loss:0.0408
# Iteration:460, Loss:0.0034
# Iteration:470, Loss:0.0036
# Iteration:480, Loss:0.0019
# Iteration:490, Loss:0.0071
# Iteration:500, Loss:0.0064
# Iteration:510, Loss:0.0108
# Iteration:520, Loss:0.0070
# Iteration:530, Loss:0.0069
# Iteration:540, Loss:0.0319
# Iteration:550, Loss:0.0204
# Iteration:560, Loss:0.0156
# Iteration:570, Loss:0.0122
# Iteration:580, Loss:0.0086
# Iteration:590, Loss:0.0040
# Iteration:600, Loss:0.0055
# Iteration:610, Loss:0.0040
# Iteration:620, Loss:0.0018
# Iteration:630, Loss:0.0133
# Iteration:640, Loss:0.0056
# Iteration:650, Loss:0.0001
# Iteration:660, Loss:0.0083
# Iteration:670, Loss:0.0110
# Iteration:680, Loss:0.0002
# Iteration:690, Loss:0.0169
# Iteration:700, Loss:0.0036
# Iteration:710, Loss:0.0040
# Iteration:720, Loss:0.0009
# Iteration:730, Loss:0.0035
# Iteration:740, Loss:0.0042
# Iteration:750, Loss:0.0073
# Iteration:760, Loss:0.0096
# Iteration:770, Loss:0.0073
# Iteration:780, Loss:0.0075
# Iteration:790, Loss:0.0082
# Iteration:800, Loss:0.0115
# Iteration:810, Loss:0.0080
# Iteration:820, Loss:0.0016
# Iteration:830, Loss:0.0040
# Iteration:840, Loss:0.0097
# Iteration:850, Loss:0.0215
# Iteration:860, Loss:0.0016
# Iteration:870, Loss:0.0056
# Iteration:880, Loss:0.0082
# Iteration:890, Loss:0.0054
# Iteration:900, Loss:0.0021
# Iteration:910, Loss:0.0078
# Iteration:920, Loss:0.0079
# Iteration:930, Loss:0.0026
# Iteration:940, Loss:0.0049
# Iteration:950, Loss:0.0001
# Iteration:960, Loss:0.0155
# Iteration:970, Loss:0.0047
# Iteration:980, Loss:0.0049
# Iteration:990, Loss:0.0056
# Iteration:1000, Loss:0.0045
# Iteration:1010, Loss:0.0106
# Iteration:1020, Loss:0.0153
# Iteration:1030, Loss:0.0006
# Iteration:1040, Loss:0.0048
# Iteration:1050, Loss:0.0105
# Iteration:1060, Loss:0.0015
# Iteration:1070, Loss:0.0268
# Iteration:1080, Loss:0.0070
# Iteration:1090, Loss:0.0106
# Iteration:1100, Loss:0.0019
# Iteration:1110, Loss:0.0024
# Iteration:1120, Loss:0.0181
# Iteration:1130, Loss:0.0174
# Iteration:1140, Loss:0.0044
# Iteration:1150, Loss:0.0008
# Iteration:1160, Loss:0.0028
# Iteration:1170, Loss:0.0006
# Iteration:1180, Loss:0.0047
# Iteration:1190, Loss:0.0023
# Iteration:1200, Loss:0.0275
# Iteration:1210, Loss:0.0023
# Iteration:1220, Loss:0.0072
# Iteration:1230, Loss:0.0325
# Iteration:1240, Loss:0.0043
# Iteration:1250, Loss:0.0004
# Iteration:1260, Loss:0.0121
# Iteration:1270, Loss:0.0197
# Iteration:1280, Loss:0.0002
# Iteration:1290, Loss:0.0116
# Iteration:1300, Loss:0.0005
# Iteration:1310, Loss:0.0082
# Iteration:1320, Loss:0.0093
# Iteration:1330, Loss:0.0134
# Iteration:1340, Loss:0.0261
# Iteration:1350, Loss:0.0078
# Iteration:1360, Loss:0.0005
# Iteration:1370, Loss:0.0175
# Iteration:1380, Loss:0.0047
# Iteration:1390, Loss:0.0067
# Iteration:1400, Loss:0.0000
# Iteration:1410, Loss:0.0178
# Iteration:1420, Loss:0.0003
# Iteration:1430, Loss:0.0100
# Iteration:1440, Loss:0.0008
# Iteration:1450, Loss:0.0041
# Iteration:1460, Loss:0.0130
# Iteration:1470, Loss:0.0017
# Iteration:1480, Loss:0.0093
# Iteration:1490, Loss:0.0063
# Iteration:1500, Loss:0.0054
# Iteration:1510, Loss:0.0190
# Iteration:1520, Loss:0.0083
# Iteration:1530, Loss:0.0081
# Iteration:1540, Loss:0.0009
# Iteration:1550, Loss:0.0179
# Iteration:1560, Loss:0.0187
# Iteration:1570, Loss:0.0012
# Iteration:1580, Loss:0.0005
# Iteration:1590, Loss:0.0027
# Iteration:1600, Loss:0.0102
# Iteration:1610, Loss:0.0053
# Iteration:1620, Loss:0.0364
# Iteration:1630, Loss:0.0035
# Iteration:1640, Loss:0.0061
# Iteration:1650, Loss:0.0210
# Iteration:1660, Loss:0.0007
# Iteration:1670, Loss:0.0016
# Iteration:1680, Loss:0.0033
# Iteration:1690, Loss:0.0024
# Iteration:1700, Loss:0.0011
# Iteration:1710, Loss:0.0066
# Iteration:1720, Loss:0.0002
# Iteration:1730, Loss:0.0047
# Iteration:1740, Loss:0.0155
# Iteration:1750, Loss:0.0036
# Iteration:1760, Loss:0.0066
# Iteration:1770, Loss:0.0003
# Iteration:1780, Loss:0.0163
# Iteration:1790, Loss:0.0025
# Iteration:1800, Loss:0.0124
# Iteration:1810, Loss:0.0054
# Iteration:1820, Loss:0.0080
# Iteration:1830, Loss:0.0144
# Iteration:1840, Loss:0.0212
# Iteration:1850, Loss:0.0091
# Iteration:1860, Loss:0.0114
# Iteration:1870, Loss:0.0068
# Iteration:1880, Loss:0.0062
# Iteration:1890, Loss:0.0013
# Iteration:1900, Loss:0.0004
# Iteration:1910, Loss:0.0039
# Iteration:1920, Loss:0.0069
# Iteration:1930, Loss:0.0040
# Iteration:1940, Loss:0.0024
# Iteration:1950, Loss:0.0001
# Iteration:1960, Loss:0.0079
# Iteration:1970, Loss:0.0007
# Iteration:1980, Loss:0.0119
# Iteration:1990, Loss:0.0009
# Iteration:2000, Loss:0.0060
# Iteration:2010, Loss:0.0096
# Iteration:2020, Loss:0.0104
# Iteration:2030, Loss:0.0081
# Iteration:2040, Loss:0.0155
# Iteration:2050, Loss:0.0113
# Iteration:2060, Loss:0.0042
# Iteration:2070, Loss:0.0101
# Iteration:2080, Loss:0.0037
# Iteration:2090, Loss:0.0171
# Iteration:2100, Loss:0.0020
# Iteration:2110, Loss:0.0020
# Iteration:2120, Loss:0.0002
# Iteration:2130, Loss:0.0008
# Iteration:2140, Loss:0.0031
# Iteration:2150, Loss:0.0063
# Iteration:2160, Loss:0.0018
# Iteration:2170, Loss:0.0006
# Iteration:2180, Loss:0.0110
# Iteration:2190, Loss:0.0199
# Iteration:2200, Loss:0.0022
# Iteration:2210, Loss:0.0013
# Iteration:2220, Loss:0.0070
# Iteration:2230, Loss:0.0068
# Iteration:2240, Loss:0.0027
# Iteration:2250, Loss:0.0038
# Iteration:2260, Loss:0.0157
# Iteration:2270, Loss:0.0147
# Iteration:2280, Loss:0.0056
# Iteration:2290, Loss:0.0140
# Iteration:2300, Loss:0.0047
# Iteration:2310, Loss:0.0479
# Iteration:2320, Loss:0.0078
# Iteration:2330, Loss:0.0161
# Iteration:2340, Loss:0.0068
# Iteration:2350, Loss:0.0105
# Iteration:2360, Loss:0.0077
# Iteration:2370, Loss:0.0018
# Iteration:2380, Loss:0.0154
# Iteration:2390, Loss:0.0073
# Iteration:2400, Loss:0.0010
# Iteration:2410, Loss:0.0040
# Iteration:2420, Loss:0.0207
# Iteration:2430, Loss:0.0025
# Iteration:2440, Loss:0.0085
# Iteration:2450, Loss:0.0310
# Iteration:2460, Loss:0.0048
# Iteration:2470, Loss:0.0029
# Iteration:2480, Loss:0.0094
# Iteration:2490, Loss:0.0111
# Iteration:2500, Loss:0.0009
# Iteration:2510, Loss:0.0036
# Iteration:2520, Loss:0.0089
# Iteration:2530, Loss:0.0088
# Iteration:2540, Loss:0.0052
# Iteration:2550, Loss:0.0058
# Iteration:2560, Loss:0.0008
# Iteration:2570, Loss:0.0018
# Iteration:2580, Loss:0.0094
# Iteration:2590, Loss:0.0140
# Iteration:2600, Loss:0.0047
# Iteration:2610, Loss:0.0068
# Iteration:2620, Loss:0.0040
# Iteration:2630, Loss:0.0008
# Iteration:2640, Loss:0.0101
# Iteration:2650, Loss:0.0040
# Iteration:2660, Loss:0.0125
# Iteration:2670, Loss:0.0028
# Iteration:2680, Loss:0.0015
# Iteration:2690, Loss:0.0050
# Iteration:2700, Loss:0.0003
# Iteration:2710, Loss:0.0020
# Iteration:2720, Loss:0.0024
# Iteration:2730, Loss:0.0179
# Iteration:2740, Loss:0.0022
# Iteration:2750, Loss:0.0062
# Iteration:2760, Loss:0.0014
# Iteration:2770, Loss:0.0102
# Iteration:2780, Loss:0.0030
# Iteration:2790, Loss:0.0025
# Iteration:2800, Loss:0.0003
# Iteration:2810, Loss:0.0002
# Iteration:2820, Loss:0.0023
# Iteration:2830, Loss:0.0061
# Iteration:2840, Loss:0.0050
# Iteration:2850, Loss:0.0039
# Iteration:2860, Loss:0.0005
# Iteration:2870, Loss:0.0001
# Iteration:2880, Loss:0.0076
# Iteration:2890, Loss:0.0034
# Iteration:2900, Loss:0.0296
# Iteration:2910, Loss:0.0034
# Iteration:2920, Loss:0.0003
# Iteration:2930, Loss:0.0023
# Iteration:2940, Loss:0.0016
# Iteration:2950, Loss:0.0023
# Iteration:2960, Loss:0.0027
# Iteration:2970, Loss:0.0041
# Iteration:2980, Loss:0.0004
# Iteration:2990, Loss:0.0149
# Iteration:3000, Loss:0.0093
# Iteration:3010, Loss:0.0129
# Iteration:3020, Loss:0.0085
# Iteration:3030, Loss:0.0094
# Iteration:3040, Loss:0.0192
# Iteration:3050, Loss:0.0289
# Iteration:3060, Loss:0.0175
# Iteration:3070, Loss:0.0086
# Iteration:3080, Loss:0.0060
# Iteration:3090, Loss:0.0060
# Iteration:3100, Loss:0.0013
# Iteration:3110, Loss:0.0174
# Iteration:3120, Loss:0.0914
# Iteration:3130, Loss:0.0030
# Iteration:3140, Loss:0.0009
# Iteration:3150, Loss:0.0070
# Iteration:3160, Loss:0.0030
# Iteration:3170, Loss:0.0098
# Iteration:3180, Loss:0.0009
# Iteration:3190, Loss:0.0029
# Iteration:3200, Loss:0.0086
# Iteration:3210, Loss:0.0039
# Iteration:3220, Loss:0.0004
# Iteration:3230, Loss:0.0009
# Iteration:3240, Loss:0.0072
# Iteration:3250, Loss:0.0014
# Iteration:3260, Loss:0.0287
# Iteration:3270, Loss:0.0015
# Iteration:3280, Loss:0.0110
# Iteration:3290, Loss:0.0055
# Iteration:3300, Loss:0.0237
# Iteration:3310, Loss:0.0076
# Iteration:3320, Loss:0.0074
# Iteration:3330, Loss:0.0004
# Iteration:3340, Loss:0.0010
# Iteration:3350, Loss:0.0027
# Iteration:3360, Loss:0.0001
# Iteration:3370, Loss:0.0048
# Iteration:3380, Loss:0.0002
# Iteration:3390, Loss:0.0011
# Iteration:3400, Loss:0.0004
# Iteration:3410, Loss:0.0056
# Iteration:3420, Loss:0.0085
# Iteration:3430, Loss:0.0052
# Iteration:3440, Loss:0.0082
# Iteration:3450, Loss:0.0101
# Iteration:3460, Loss:0.0007
# Iteration:3470, Loss:0.0003
# Iteration:3480, Loss:0.0059
# Iteration:3490, Loss:0.0007
# Iteration:3500, Loss:0.0028
# Iteration:3510, Loss:0.0011
# Iteration:3520, Loss:0.0035
# Iteration:3530, Loss:0.0058
# Iteration:3540, Loss:0.0127
# Iteration:3550, Loss:0.0124
# Iteration:3560, Loss:0.0106
# Iteration:3570, Loss:0.0001
# Iteration:3580, Loss:0.0033
# Iteration:3590, Loss:0.0069
# Iteration:3600, Loss:0.0088
# Iteration:3610, Loss:0.0195
# Iteration:3620, Loss:0.0104
# Iteration:3630, Loss:0.0014
# Iteration:3640, Loss:0.0071
# Iteration:3650, Loss:0.0068
# Iteration:3660, Loss:0.0227
# Iteration:3670, Loss:0.0069
# Iteration:3680, Loss:0.0033
# Iteration:3690, Loss:0.0025
# Iteration:3700, Loss:0.0080
# Iteration:3710, Loss:0.0020
# Iteration:3720, Loss:0.0037
# Iteration:3730, Loss:0.0032
# Iteration:3740, Loss:0.0216
# Iteration:3750, Loss:0.0188
# Iteration:3760, Loss:0.0015
# Iteration:3770, Loss:0.0083
# Iteration:3780, Loss:0.0040
# Iteration:3790, Loss:0.0053
# Iteration:3800, Loss:0.0079
# Iteration:3810, Loss:0.0139
# Iteration:3820, Loss:0.0097
# Iteration:3830, Loss:0.0004
# Iteration:3840, Loss:0.0006
# Iteration:3850, Loss:0.0089
# Iteration:3860, Loss:0.0008
# Iteration:3870, Loss:0.0015
# Iteration:3880, Loss:0.0122
# Iteration:3890, Loss:0.0062
# Iteration:3900, Loss:0.0036
# Iteration:3910, Loss:0.0105
# Iteration:3920, Loss:0.0082
# Iteration:3930, Loss:0.0002
# Iteration:3940, Loss:0.0019
# Iteration:3950, Loss:0.0005
# Iteration:3960, Loss:0.0032
# Iteration:3970, Loss:0.0004
# Iteration:3980, Loss:0.0014
# Iteration:3990, Loss:0.0014
# Iteration:4000, Loss:0.0023
# Iteration:4010, Loss:0.0029
# Iteration:4020, Loss:0.0005
# Iteration:4030, Loss:0.0028
# Iteration:4040, Loss:0.0022
# Iteration:4050, Loss:0.0022
# Iteration:4060, Loss:0.0033
# Iteration:4070, Loss:0.0008
# Iteration:4080, Loss:0.0003
# Iteration:4090, Loss:0.0020
# Iteration:4100, Loss:0.0042
# Iteration:4110, Loss:0.0046
# Iteration:4120, Loss:0.0006
# Iteration:4130, Loss:0.0005
# Iteration:4140, Loss:0.0037
# Iteration:4150, Loss:0.0042
# Iteration:4160, Loss:0.0073
# Iteration:4170, Loss:0.0034
# Iteration:4180, Loss:0.0020
# Iteration:4190, Loss:0.0000
# Iteration:4200, Loss:0.0016
# Iteration:4210, Loss:0.0007
# Iteration:4220, Loss:0.0025
# Iteration:4230, Loss:0.0040
# Iteration:4240, Loss:0.0002
# Iteration:4250, Loss:0.0022
# Iteration:4260, Loss:0.0029
# Iteration:4270, Loss:0.0018
# Iteration:4280, Loss:0.0095
# Iteration:4290, Loss:0.0046
# Iteration:4300, Loss:0.0051
# Iteration:4310, Loss:0.0037
# Iteration:4320, Loss:0.0002
# Iteration:4330, Loss:0.0031
# Iteration:4340, Loss:0.0018
# Iteration:4350, Loss:0.0050
# Iteration:4360, Loss:0.0002
# Iteration:4370, Loss:0.0154
# Iteration:4380, Loss:0.0012
# Iteration:4390, Loss:0.0096
# Iteration:4400, Loss:0.0034
# Iteration:4410, Loss:0.0052
# Iteration:4420, Loss:0.0042
# Iteration:4430, Loss:0.0094
# Iteration:4440, Loss:0.0029
# Iteration:4450, Loss:0.0031
# Iteration:4460, Loss:0.0140
# Iteration:4470, Loss:0.0026
# Iteration:4480, Loss:0.0029
# Iteration:4490, Loss:0.0013
# Iteration:4500, Loss:0.0003
# Iteration:4510, Loss:0.0007
# Iteration:4520, Loss:0.0146
# Iteration:4530, Loss:0.0037
# Iteration:4540, Loss:0.0018
# Iteration:4550, Loss:0.0069
# Iteration:4560, Loss:0.0038
# Iteration:4570, Loss:0.0035
# Iteration:4580, Loss:0.0094
# Iteration:4590, Loss:0.0037
# Iteration:4600, Loss:0.0088
# Iteration:4610, Loss:0.0073
# Iteration:4620, Loss:0.0214
# Iteration:4630, Loss:0.0041
# Iteration:4640, Loss:0.0024
# Iteration:4650, Loss:0.0012
# Iteration:4660, Loss:0.0090
# Iteration:4670, Loss:0.0004
# Iteration:4680, Loss:0.0038
# Iteration:4690, Loss:0.0087
# Iteration:4700, Loss:0.0036
# Iteration:4710, Loss:0.0002
# Iteration:4720, Loss:0.0012
# Iteration:4730, Loss:0.0017
# Iteration:4740, Loss:0.0005
# Iteration:4750, Loss:0.0032
# Iteration:4760, Loss:0.0012
# Iteration:4770, Loss:0.0044
# Iteration:4780, Loss:0.0021
# Iteration:4790, Loss:0.0054
# Iteration:4800, Loss:0.0064
# Iteration:4810, Loss:0.0044
# Iteration:4820, Loss:0.0035
# Iteration:4830, Loss:0.0010
# Iteration:4840, Loss:0.0003
# Iteration:4850, Loss:0.0012
# Iteration:4860, Loss:0.0005
# Iteration:4870, Loss:0.0059
# Iteration:4880, Loss:0.0048
# Iteration:4890, Loss:0.0032
# Iteration:4900, Loss:0.0076
# Iteration:4910, Loss:0.0027
# Iteration:4920, Loss:0.0011
# Iteration:4930, Loss:0.0043
# Iteration:4940, Loss:0.0046
# Iteration:4950, Loss:0.0074
# Iteration:4960, Loss:0.0019
# Iteration:4970, Loss:0.0028
# Iteration:4980, Loss:0.0072
# Iteration:4990, Loss:0.0014
# Iteration:5000, Loss:0.0083
# Iteration:5010, Loss:0.0013
# Iteration:5020, Loss:0.0018
# Iteration:5030, Loss:0.0052
# Iteration:5040, Loss:0.0082
# Iteration:5050, Loss:0.0061
# Iteration:5060, Loss:0.0329
# Iteration:5070, Loss:0.0066
# Iteration:5080, Loss:0.0003
# Iteration:5090, Loss:0.0075
# Iteration:5100, Loss:0.0117
# Iteration:5110, Loss:0.0024
# Iteration:5120, Loss:0.0027
# Iteration:5130, Loss:0.0015
# Iteration:5140, Loss:0.0037
# Iteration:5150, Loss:0.0035
# Iteration:5160, Loss:0.0001
# Iteration:5170, Loss:0.0103
# Iteration:5180, Loss:0.0002
# Iteration:5190, Loss:0.0018
# Iteration:5200, Loss:0.0032
# Iteration:5210, Loss:0.0056
# Iteration:5220, Loss:0.0062
# Iteration:5230, Loss:0.0082
# Iteration:5240, Loss:0.0080
# Iteration:5250, Loss:0.0026
# Iteration:5260, Loss:0.0060
# Iteration:5270, Loss:0.0013
# Iteration:5280, Loss:0.0016
# Iteration:5290, Loss:0.0016
# Iteration:5300, Loss:0.0019
# Iteration:5310, Loss:0.0060
# Iteration:5320, Loss:0.0067
# Iteration:5330, Loss:0.0059
# Iteration:5340, Loss:0.0024
# Iteration:5350, Loss:0.0089
# Iteration:5360, Loss:0.0069
# Iteration:5370, Loss:0.0029
# Iteration:5380, Loss:0.0069
# Iteration:5390, Loss:0.0081
# Iteration:5400, Loss:0.0119
# Iteration:5410, Loss:0.0129
# Iteration:5420, Loss:0.0088
# Iteration:5430, Loss:0.0119
# Iteration:5440, Loss:0.0100
# Iteration:5450, Loss:0.0103
# Iteration:5460, Loss:0.0066
# Iteration:5470, Loss:0.0027
# Iteration:5480, Loss:0.0024
# Iteration:5490, Loss:0.0188
# Iteration:5500, Loss:0.0100
# Iteration:5510, Loss:0.0109
# Iteration:5520, Loss:0.0008
# Iteration:5530, Loss:0.0054
# Iteration:5540, Loss:0.0001
# Iteration:5550, Loss:0.0029
# Iteration:5560, Loss:0.0007
# Iteration:5570, Loss:0.0195
# Iteration:5580, Loss:0.0063
# Iteration:5590, Loss:0.0104
# Iteration:5600, Loss:0.0043
# Iteration:5610, Loss:0.0263
# Iteration:5620, Loss:0.0010
# Iteration:5630, Loss:0.0084
# Iteration:5640, Loss:0.0197
# Iteration:5650, Loss:0.0004
# Iteration:5660, Loss:0.0043
# Iteration:5670, Loss:0.0145
# Iteration:5680, Loss:0.0030
# Iteration:5690, Loss:0.0032
# Iteration:5700, Loss:0.0004
# Iteration:5710, Loss:0.0069
# Iteration:5720, Loss:0.0110
# Iteration:5730, Loss:0.0060
# Iteration:5740, Loss:0.0059
# Iteration:5750, Loss:0.0061
# Iteration:5760, Loss:0.0084
# Iteration:5770, Loss:0.0004
# Iteration:5780, Loss:0.0027
# Iteration:5790, Loss:0.0088
# Iteration:5800, Loss:0.0080
# Iteration:5810, Loss:0.0035
# Iteration:5820, Loss:0.0062
# Iteration:5830, Loss:0.0065
# Iteration:5840, Loss:0.0048
# Iteration:5850, Loss:0.0048
# Iteration:5860, Loss:0.0098
# Iteration:5870, Loss:0.0002
# Iteration:5880, Loss:0.0101
# Iteration:5890, Loss:0.0009
# Iteration:5900, Loss:0.0018
# Iteration:5910, Loss:0.0022
# Iteration:5920, Loss:0.0060
# Iteration:5930, Loss:0.0078
# Iteration:5940, Loss:0.0049
# Iteration:5950, Loss:0.0493
# Iteration:5960, Loss:0.0038
# Iteration:5970, Loss:0.0005
# Iteration:5980, Loss:0.0014
# Iteration:5990, Loss:0.0006
# Iteration:6000, Loss:0.0105
# Iteration:6010, Loss:0.0050
# Iteration:6020, Loss:0.0160
# Iteration:6030, Loss:0.0107
# Iteration:6040, Loss:0.0061
# Iteration:6050, Loss:0.0009
# Iteration:6060, Loss:0.0008
# Iteration:6070, Loss:0.0105
# Iteration:6080, Loss:0.0036
# Iteration:6090, Loss:0.0193
# Iteration:6100, Loss:0.0022
# Iteration:6110, Loss:0.0011
# Iteration:6120, Loss:0.0179
# Iteration:6130, Loss:0.0007
# Iteration:6140, Loss:0.0008
# Iteration:6150, Loss:0.0046
# Iteration:6160, Loss:0.0008
# Iteration:6170, Loss:0.0051
# Iteration:6180, Loss:0.0014
# Iteration:6190, Loss:0.0015
# Iteration:6200, Loss:0.0116
# Iteration:6210, Loss:0.0016
# Iteration:6220, Loss:0.0050
# Iteration:6230, Loss:0.0042
# Iteration:6240, Loss:0.0265
# Iteration:6250, Loss:0.0059
# Iteration:6260, Loss:0.0004
# Iteration:6270, Loss:0.0010
# Iteration:6280, Loss:0.0620
# Iteration:6290, Loss:0.0015
# Iteration:6300, Loss:0.0044
# Iteration:6310, Loss:0.0051
# Iteration:6320, Loss:0.0080
# Iteration:6330, Loss:0.0000
# Iteration:6340, Loss:0.0071
# Iteration:6350, Loss:0.0055
# Iteration:6360, Loss:0.0124
# Iteration:6370, Loss:0.0035
# Iteration:6380, Loss:0.0010
# Iteration:6390, Loss:0.0026
# Iteration:6400, Loss:0.0176
# Iteration:6410, Loss:0.0017
# Iteration:6420, Loss:0.0343
# Iteration:6430, Loss:0.0023
# Iteration:6440, Loss:0.0007
# Iteration:6450, Loss:0.0064
# Iteration:6460, Loss:0.0006
# Iteration:6470, Loss:0.0006
# Iteration:6480, Loss:0.0064
# Iteration:6490, Loss:0.0121
# Iteration:6500, Loss:0.0008
# Iteration:6510, Loss:0.0021
# Iteration:6520, Loss:0.0007
# Iteration:6530, Loss:0.0001
# Iteration:6540, Loss:0.0031
# Iteration:6550, Loss:0.0107
# Iteration:6560, Loss:0.0090
# Iteration:6570, Loss:0.0016
# Iteration:6580, Loss:0.0082
# Iteration:6590, Loss:0.0001
# Iteration:6600, Loss:0.0045
# Iteration:6610, Loss:0.0020
# Iteration:6620, Loss:0.0005
# Iteration:6630, Loss:0.0128
# Iteration:6640, Loss:0.0039
# Iteration:6650, Loss:0.0124
# Iteration:6660, Loss:0.0003
# Iteration:6670, Loss:0.0014
# Iteration:6680, Loss:0.0031
# Iteration:6690, Loss:0.0068
# Iteration:6700, Loss:0.0022
# Iteration:6710, Loss:0.0002
# Iteration:6720, Loss:0.0030
# Iteration:6730, Loss:0.0019
# Iteration:6740, Loss:0.0020
# Iteration:6750, Loss:0.0032
# Iteration:6760, Loss:0.0003
# Iteration:6770, Loss:0.0017
# Iteration:6780, Loss:0.0010
# Iteration:6790, Loss:0.0101
# Iteration:6800, Loss:0.0040
# Iteration:6810, Loss:0.0052
# Iteration:6820, Loss:0.0040
# Iteration:6830, Loss:0.0352
# Iteration:6840, Loss:0.0290
# Iteration:6850, Loss:0.0016
# Iteration:6860, Loss:0.0007
# Iteration:6870, Loss:0.0081
# Iteration:6880, Loss:0.0011
# Iteration:6890, Loss:0.0011
# Iteration:6900, Loss:0.0013
# Iteration:6910, Loss:0.0010
# Iteration:6920, Loss:0.0035
# Iteration:6930, Loss:0.0001
# Iteration:6940, Loss:0.0008
# Iteration:6950, Loss:0.0005
# Iteration:6960, Loss:0.0006
# Iteration:6970, Loss:0.0130
# Iteration:6980, Loss:0.0017
# Iteration:6990, Loss:0.0042
# Iteration:7000, Loss:0.0017
# Iteration:7010, Loss:0.0013
# Iteration:7020, Loss:0.0284
# Iteration:7030, Loss:0.0000
# Iteration:7040, Loss:0.0016
# Iteration:7050, Loss:0.0010
# Iteration:7060, Loss:0.0067
# Iteration:7070, Loss:0.0212
# Iteration:7080, Loss:0.0007
# Iteration:7090, Loss:0.0000
# Iteration:7100, Loss:0.0013
# Iteration:7110, Loss:0.0004
# Iteration:7120, Loss:0.0030
# Iteration:7130, Loss:0.0095
# Iteration:7140, Loss:0.0286
# Iteration:7150, Loss:0.0024
# Iteration:7160, Loss:0.0012
# Iteration:7170, Loss:0.0033
# Iteration:7180, Loss:0.0010
# Iteration:7190, Loss:0.0554
# Iteration:7200, Loss:0.0053
# Iteration:7210, Loss:0.0139
# Iteration:7220, Loss:0.0023
# Iteration:7230, Loss:0.0110
# Iteration:7240, Loss:0.0008
# Iteration:7250, Loss:0.0046
# Iteration:7260, Loss:0.0029
# Iteration:7270, Loss:0.0000
# Iteration:7280, Loss:0.0002
# Iteration:7290, Loss:0.0055
# Iteration:7300, Loss:0.0006
# Iteration:7310, Loss:0.0066
# Iteration:7320, Loss:0.0073
# Iteration:7330, Loss:0.0021
# Iteration:7340, Loss:0.0056
# Iteration:7350, Loss:0.0013
# Iteration:7360, Loss:0.0005
# Iteration:7370, Loss:0.0191
# Iteration:7380, Loss:0.0008
# Iteration:7390, Loss:0.0048
# Iteration:7400, Loss:0.0106
# Iteration:7410, Loss:0.0007
# Iteration:7420, Loss:0.0021
# Iteration:7430, Loss:0.0014
# Iteration:7440, Loss:0.0048
# Iteration:7450, Loss:0.0145
# Iteration:7460, Loss:0.0025
# Iteration:7470, Loss:0.0066
# Iteration:7480, Loss:0.0026
# Iteration:7490, Loss:0.0008
# Iteration:7500, Loss:0.0042
# Iteration:7510, Loss:0.0002
# Iteration:7520, Loss:0.0027
# Iteration:7530, Loss:0.0037
# Iteration:7540, Loss:0.0164
# Iteration:7550, Loss:0.0069
# Iteration:7560, Loss:0.0130
# Iteration:7570, Loss:0.0029
# Iteration:7580, Loss:0.0066
# Iteration:7590, Loss:0.0316
# Iteration:7600, Loss:0.0052
# Iteration:7610, Loss:0.0252
# Iteration:7620, Loss:0.0037
# Iteration:7630, Loss:0.0028
# Iteration:7640, Loss:0.0021
# Iteration:7650, Loss:0.0048
# Iteration:7660, Loss:0.0111
# Iteration:7670, Loss:0.0048
# Iteration:7680, Loss:0.0038
# Iteration:7690, Loss:0.0088
# Iteration:7700, Loss:0.0093
# Iteration:7710, Loss:0.0109
# Iteration:7720, Loss:0.0056
# Iteration:7730, Loss:0.0155
# Iteration:7740, Loss:0.0063
# Iteration:7750, Loss:0.0017
# Iteration:7760, Loss:0.0066
# Iteration:7770, Loss:0.0007
# Iteration:7780, Loss:0.0022
# Iteration:7790, Loss:0.0170
# Iteration:7800, Loss:0.0005
# Iteration:7810, Loss:0.0005
# Iteration:7820, Loss:0.0138
# Iteration:7830, Loss:0.0043
# Iteration:7840, Loss:0.0009
# Iteration:7850, Loss:0.0071
# Iteration:7860, Loss:0.0009
# Iteration:7870, Loss:0.0050
# Iteration:7880, Loss:0.0054
# Iteration:7890, Loss:0.0022
# Iteration:7900, Loss:0.0014
# Iteration:7910, Loss:0.0026
# Iteration:7920, Loss:0.0052
# Iteration:7930, Loss:0.0029
# Iteration:7940, Loss:0.0007
# Iteration:7950, Loss:0.0036
# Iteration:7960, Loss:0.0008
# Iteration:7970, Loss:0.0021
# Iteration:7980, Loss:0.0010
# Iteration:7990, Loss:0.0041
# Iteration:8000, Loss:0.0013
# Iteration:8010, Loss:0.0025
# Iteration:8020, Loss:0.0032
# Iteration:8030, Loss:0.0011
# Iteration:8040, Loss:0.0036
# Iteration:8050, Loss:0.0030
# Iteration:8060, Loss:0.0064
# Iteration:8070, Loss:0.0001
# Iteration:8080, Loss:0.0016
# Iteration:8090, Loss:0.0003
# Iteration:8100, Loss:0.0004
# Iteration:8110, Loss:0.0085
# Iteration:8120, Loss:0.0002
# Iteration:8130, Loss:0.0026
# Iteration:8140, Loss:0.0043
# Iteration:8150, Loss:0.0085
# Iteration:8160, Loss:0.0092
# Iteration:8170, Loss:0.0024
# Iteration:8180, Loss:0.0036
# Iteration:8190, Loss:0.0005
# Iteration:8200, Loss:0.0038
# Iteration:8210, Loss:0.0005
# Iteration:8220, Loss:0.0035
# Iteration:8230, Loss:0.0013
# Iteration:8240, Loss:0.0041
# Iteration:8250, Loss:0.0028
# Iteration:8260, Loss:0.0072
# Iteration:8270, Loss:0.0063
# Iteration:8280, Loss:0.0243
# Iteration:8290, Loss:0.0181
# Iteration:8300, Loss:0.0034
# Iteration:8310, Loss:0.0017
# Iteration:8320, Loss:0.0504
# Iteration:8330, Loss:0.0067
# Iteration:8340, Loss:0.0082
# Iteration:8350, Loss:0.0068
# Iteration:8360, Loss:0.0039
# Iteration:8370, Loss:0.0028
# Iteration:8380, Loss:0.0015
# Iteration:8390, Loss:0.0033
# Iteration:8400, Loss:0.0041
# Iteration:8410, Loss:0.0007
# Iteration:8420, Loss:0.0060
# Iteration:8430, Loss:0.0018
# Iteration:8440, Loss:0.0010
# Iteration:8450, Loss:0.0034
# Iteration:8460, Loss:0.0001
# Iteration:8470, Loss:0.0146
# Iteration:8480, Loss:0.0008
# Iteration:8490, Loss:0.0021
# Iteration:8500, Loss:0.0051
# Iteration:8510, Loss:0.0025
# Iteration:8520, Loss:0.0031
# Iteration:8530, Loss:0.0035
# Iteration:8540, Loss:0.0024
# Iteration:8550, Loss:0.0047
# Iteration:8560, Loss:0.0032
# Iteration:8570, Loss:0.0042
# Iteration:8580, Loss:0.0004
# Iteration:8590, Loss:0.0033
# Iteration:8600, Loss:0.0032
# Iteration:8610, Loss:0.0023
# Iteration:8620, Loss:0.0028
# Iteration:8630, Loss:0.0017
# Iteration:8640, Loss:0.0008
# Iteration:8650, Loss:0.0035
# Iteration:8660, Loss:0.0002
# Iteration:8670, Loss:0.0128
# Iteration:8680, Loss:0.0069
# Iteration:8690, Loss:0.0003
# Iteration:8700, Loss:0.0123
# Iteration:8710, Loss:0.0171
# Iteration:8720, Loss:0.0006
# Iteration:8730, Loss:0.0015
# Iteration:8740, Loss:0.0052
# Iteration:8750, Loss:0.0019
# Iteration:8760, Loss:0.0149
# Iteration:8770, Loss:0.0124
# Iteration:8780, Loss:0.0014
# Iteration:8790, Loss:0.0071
# Iteration:8800, Loss:0.0001
# Iteration:8810, Loss:0.0033
# Iteration:8820, Loss:0.0030
# Iteration:8830, Loss:0.0107
# Iteration:8840, Loss:0.0059
# Iteration:8850, Loss:0.0030
# Iteration:8860, Loss:0.0060
# Iteration:8870, Loss:0.0012
# Iteration:8880, Loss:0.0051
# Iteration:8890, Loss:0.0109
# Iteration:8900, Loss:0.0063
# Iteration:8910, Loss:0.0039
# Iteration:8920, Loss:0.0097
# Iteration:8930, Loss:0.0028
# Iteration:8940, Loss:0.0102
# Iteration:8950, Loss:0.0017
# Iteration:8960, Loss:0.0021
# Iteration:8970, Loss:0.0076
# Iteration:8980, Loss:0.0142
# Iteration:8990, Loss:0.0026
# Iteration:9000, Loss:0.0001
# Iteration:9010, Loss:0.0369
# Iteration:9020, Loss:0.0131
# Iteration:9030, Loss:0.0050
# Iteration:9040, Loss:0.0023
# Iteration:9050, Loss:0.0055
# Iteration:9060, Loss:0.0143
# Iteration:9070, Loss:0.0025
# Iteration:9080, Loss:0.0099
# Iteration:9090, Loss:0.0073
# Iteration:9100, Loss:0.0087
# Iteration:9110, Loss:0.0091
# Iteration:9120, Loss:0.0014
# Iteration:9130, Loss:0.0053
# tensor(0.4826, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4379, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4690, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4863, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4698, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4705, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4369, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4482, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4463, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4356, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4409, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4527, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4513, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4532, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4759, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4568, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4284, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4568, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4920, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4402, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4438, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4149, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4570, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4258, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4348, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4434, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4576, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4634, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4624, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4440, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4700, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4563, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4528, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4649, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4908, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.5002, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4600, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4672, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4588, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4537, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4444, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4394, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4708, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4765, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4545, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4643, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4429, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4451, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4749, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4955, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4922, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4898, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4673, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4659, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4562, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4831, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4471, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4644, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4998, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4610, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4390, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4591, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4834, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4452, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4811, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4477, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4691, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4696, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4497, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4621, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4693, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4599, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4943, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4682, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4492, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4908, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4403, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4967, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4869, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4417, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4449, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4465, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4702, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4317, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4150, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4694, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4297, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4148, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4696, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4689, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4694, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4753, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4826, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4765, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4934, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.5014, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4995, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4538, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4981, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4544, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4854, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4935, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4950, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4784, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.5172, grad_fn=<SelectBackward>)
# tensor(0.5156)
# tensor(0.4399, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4607, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4645, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4760, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4946, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4532, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4665, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4474, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4539, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4567, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4601, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4721, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4596, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4835, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4820, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4691, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4701, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4669, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4484, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4747, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4530, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4953, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4529, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4795, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4692, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4684, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4936, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4904, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4806, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4680, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4423, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4506, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4747, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4639, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4785, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4518, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4842, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4685, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4734, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4624, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4659, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4660, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4451, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4963, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4888, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4768, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4854, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4616, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4502, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4396, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4694, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4647, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4906, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4469, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4629, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4919, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4376, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.5087, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4784, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4815, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4567, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4764, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4225, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4580, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4864, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4598, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4152, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4542, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4536, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4842, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4654, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4757, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4446, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4454, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4617, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4509, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4747, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4650, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4491, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4544, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4554, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4476, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4529, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4360, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4426, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4568, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4503, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4310, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4546, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4605, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4804, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4520, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4473, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4402, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4778, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4783, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4698, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4694, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4228, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4422, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4595, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4349, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4531, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4451, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4543, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4521, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4616, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4595, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4549, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4603, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4662, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4588, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4550, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4607, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4589, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4307, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4389, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4697, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4691, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4765, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4451, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4504, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4512, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4624, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4798, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4678, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4592, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4528, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4539, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4549, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4518, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4470, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4098, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4185, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4465, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4539, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4442, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4705, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4260, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4140, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4596, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4449, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4454, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4201, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4461, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4582, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4506, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4544, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4297, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4331, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4577, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4760, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4777, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4198, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4437, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4231, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4711, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4745, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4837, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4754, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4751, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4606, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4615, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4557, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4617, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4766, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4511, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4538, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4500, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4602, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4835, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4510, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4542, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4699, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4666, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4779, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4652, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4666, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4685, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4655, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4633, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4616, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4638, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4759, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4710, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4580, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4678, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4780, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4826, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4569, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4463, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4618, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4598, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4665, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4369, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4608, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4629, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4540, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4775, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4720, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4322, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4612, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4597, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4533, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4447, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4594, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4640, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4616, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4754, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4618, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4589, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4567, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.5020, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4308, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4518, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4563, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4308, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4612, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4620, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4529, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4545, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4586, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4565, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4488, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4556, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4552, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4650, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4599, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4288, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4548, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4554, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4540, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4629, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4769, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4467, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.5065, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4629, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4704, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4728, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4450, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4164, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4670, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4418, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4560, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4557, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4321, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4546, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4831, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4140, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4528, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4726, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4744, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4626, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4573, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4311, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4537, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4517, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4691, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4384, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4501, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4660, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4947, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4711, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4469, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4538, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4441, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4633, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4559, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4526, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4284, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4596, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4723, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4513, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4715, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4464, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4607, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4766, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4603, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4766, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4389, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4116, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4582, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4239, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4470, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4566, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4610, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4703, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4637, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4559, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4524, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4367, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4298, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4417, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4228, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4366, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4687, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4461, grad_fn=<SelectBackward>)
# tensor(0.4375)
# ...
# tensor(0.4737, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4620, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4003, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4042, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4206, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4036, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4301, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4322, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4235, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4319, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4692, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4129, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4103, grad_fn=<SelectBackward>)
# tensor(0.4062)
# tensor(0.4573, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4526, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4672, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4581, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4524, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.5100, grad_fn=<SelectBackward>)
# tensor(0.5156)
# tensor(0.4521, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4858, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4515, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.5188, grad_fn=<SelectBackward>)
# tensor(0.5234)
# tensor(0.4682, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4872, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4333, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4265, grad_fn=<SelectBackward>)
# tensor(0.4219)
# tensor(0.4554, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4288, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4457, grad_fn=<SelectBackward>)
# tensor(0.4375)
# tensor(0.4581, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4606, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4323, grad_fn=<SelectBackward>)
# tensor(0.4297)
# tensor(0.4550, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4829, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4635, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4767, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.5073, grad_fn=<SelectBackward>)
# tensor(0.5156)
# tensor(0.4665, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.5053, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4688, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.5035, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4526, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4526, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.5088, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4584, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4783, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4744, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4770, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4907, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4992, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4857, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.5002, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4997, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4977, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4580, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4776, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.5014, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.4699, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4568, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4457, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4489, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4152, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4846, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4947, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.5071, grad_fn=<SelectBackward>)
# tensor(0.5000)
# tensor(0.5019, grad_fn=<SelectBackward>)
# tensor(0.4922)
# tensor(0.4536, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4186, grad_fn=<SelectBackward>)
# tensor(0.4141)
# tensor(0.4628, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4727, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4605, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.4932, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.4710, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4570, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4448, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4581, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4823, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4801, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4616, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4467, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4584, grad_fn=<SelectBackward>)
# tensor(0.4609)
# tensor(0.4697, grad_fn=<SelectBackward>)
# tensor(0.4766)
# tensor(0.4435, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4394, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4452, grad_fn=<SelectBackward>)
# tensor(0.4453)
# tensor(0.4990, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4622, grad_fn=<SelectBackward>)
# tensor(0.4531)
# tensor(0.4779, grad_fn=<SelectBackward>)
# tensor(0.4688)
# tensor(0.5175, grad_fn=<SelectBackward>)
# tensor(0.5078)
# tensor(0.4891, grad_fn=<SelectBackward>)
# tensor(0.4844)
# tensor(0.3992, grad_fn=<SelectBackward>)
# tensor(0.3906)
# tensor(0.4894, grad_fn=<SelectBackward>)
# tensor(0.4844)
# Epoch:4, Loss:0.0005, train_acc:0.059325744308231176
# predicted note:  tensor([[0.4916, 0.3334, 0.0093, 0.0297]], grad_fn=<AddmmBackward>)
# model_path:  model_LSTM_Reg_ws20_simple_model_bs128_lr0.001_epoch3
# model checkpointed
# Iteration:36550, Loss:0.0022
# Iteration:36560, Loss:0.0073
# Iteration:36570, Loss:0.0114
# Iteration:36580, Loss:0.0165
# Iteration:36590, Loss:0.0013
# Iteration:36600, Loss:0.0014
# Iteration:36610, Loss:0.0120
# Iteration:36620, Loss:0.0023
# Iteration:36630, Loss:0.0152
# Iteration:36640, Loss:0.0004
# Iteration:36650, Loss:0.0000
# Iteration:36660, Loss:0.0006
# Iteration:36670, Loss:0.0027
# Iteration:36680, Loss:0.0011
# Iteration:36690, Loss:0.0014
# Iteration:36700, Loss:0.0002
# Iteration:36710, Loss:0.0056
# Iteration:36720, Loss:0.0053
# Iteration:36730, Loss:0.0012
# Iteration:36740, Loss:0.0009
# Iteration:36750, Loss:0.0079
# Iteration:36760, Loss:0.0059
# Iteration:36770, Loss:0.0081
# Iteration:36780, Loss:0.0038
# Iteration:36790, Loss:0.0186
# Iteration:36800, Loss:0.0147
# Iteration:36810, Loss:0.0031
# Iteration:36820, Loss:0.0085
# Iteration:36830, Loss:0.0046
# Iteration:36840, Loss:0.0045
# Iteration:36850, Loss:0.0006
# Iteration:36860, Loss:0.0016
# Iteration:36870, Loss:0.0026
# Iteration:36880, Loss:0.0050
# Iteration:36890, Loss:0.0130
# Iteration:36900, Loss:0.0165
# Iteration:36910, Loss:0.0065
# Iteration:36920, Loss:0.0049
# Iteration:36930, Loss:0.0006
# Iteration:36940, Loss:0.0003
# Iteration:36950, Loss:0.0032
# Iteration:36960, Loss:0.0004
# Iteration:36970, Loss:0.0029
# Iteration:36980, Loss:0.0016
# Iteration:36990, Loss:0.0020
# Iteration:37000, Loss:0.0007
# Iteration:37010, Loss:0.0018
# Iteration:37020, Loss:0.0052
# Iteration:37030, Loss:0.0010
# Iteration:37040, Loss:0.0008
# Iteration:37050, Loss:0.0093
# Iteration:37060, Loss:0.0003
# Iteration:37070, Loss:0.0206
# Iteration:37080, Loss:0.0052
# Iteration:37090, Loss:0.0022
# Iteration:37100, Loss:0.0010
# Iteration:37110, Loss:0.0118
# Iteration:37120, Loss:0.0019
# Iteration:37130, Loss:0.0039
# Iteration:37140, Loss:0.0015
# Iteration:37150, Loss:0.0039
# Iteration:37160, Loss:0.0106
# Iteration:37170, Loss:0.0002
# Iteration:37180, Loss:0.0049
# Iteration:37190, Loss:0.0126
# Iteration:37200, Loss:0.0018
# Iteration:37210, Loss:0.0003
# Iteration:37220, Loss:0.0052
# Iteration:37230, Loss:0.0019
# Iteration:37240, Loss:0.0031
# Iteration:37250, Loss:0.0126
# Iteration:37260, Loss:0.0030
# Iteration:37270, Loss:0.0009
# Iteration:37280, Loss:0.0162
# Iteration:37290, Loss:0.0088
# Iteration:37300, Loss:0.0074
# Iteration:37310, Loss:0.0093
# Iteration:37320, Loss:0.0073
# Iteration:37330, Loss:0.0178
# Iteration:37340, Loss:0.0042
# Iteration:37350, Loss:0.0007
# Iteration:37360, Loss:0.0201
# Iteration:37370, Loss:0.0211
# Iteration:37380, Loss:0.0150
# Iteration:37390, Loss:0.0078
# Iteration:37400, Loss:0.0029
# Iteration:37410, Loss:0.0001
# Iteration:37420, Loss:0.0032
# Iteration:37430, Loss:0.0020
# Iteration:37440, Loss:0.0008
# Iteration:37450, Loss:0.0004
# Iteration:37460, Loss:0.0006
# Iteration:37470, Loss:0.0084
# Iteration:37480, Loss:0.0005
# Iteration:37490, Loss:0.0142
# Iteration:37500, Loss:0.0039
# Iteration:37510, Loss:0.0063
# Iteration:37520, Loss:0.0085
# Iteration:37530, Loss:0.0084
# Iteration:37540, Loss:0.0034
# Iteration:37550, Loss:0.0072
# Iteration:37560, Loss:0.0196
# Iteration:37570, Loss:0.0008
# Iteration:37580, Loss:0.0098
# Iteration:37590, Loss:0.0006
# Iteration:37600, Loss:0.0000
# Iteration:37610, Loss:0.0202
# Iteration:37620, Loss:0.0146
# Iteration:37630, Loss:0.0050
# Iteration:37640, Loss:0.0062
# Iteration:37650, Loss:0.0122
# Iteration:37660, Loss:0.0027
# Iteration:37670, Loss:0.0069
# Iteration:37680, Loss:0.0037
# Iteration:37690, Loss:0.0011
# Iteration:37700, Loss:0.0121
# Iteration:37710, Loss:0.0077
# Iteration:37720, Loss:0.0018
# Iteration:37730, Loss:0.0039
# Iteration:37740, Loss:0.0012
# Iteration:37750, Loss:0.0061
# Iteration:37760, Loss:0.0018
# Iteration:37770, Loss:0.0065
# Iteration:37780, Loss:0.0005
# Iteration:37790, Loss:0.0249
# Iteration:37800, Loss:0.0081
# Iteration:37810, Loss:0.0129
# Iteration:37820, Loss:0.0049
# Iteration:37830, Loss:0.0018
# Iteration:37840, Loss:0.0067
# Iteration:37850, Loss:0.0024
# Iteration:37860, Loss:0.0069
# Iteration:37870, Loss:0.0010
# Iteration:37880, Loss:0.0233
# Iteration:37890, Loss:0.0032
# Iteration:37900, Loss:0.0323
# Iteration:37910, Loss:0.0039
# Iteration:37920, Loss:0.0016
# Iteration:37930, Loss:0.0077
# Iteration:37940, Loss:0.0126
# Iteration:37950, Loss:0.0001
# Iteration:37960, Loss:0.0021
# Iteration:37970, Loss:0.0046
# Iteration:37980, Loss:0.0095
# Iteration:37990, Loss:0.0019
# Iteration:38000, Loss:0.0166
# Iteration:38010, Loss:0.0016
# Iteration:38020, Loss:0.0049
# Iteration:38030, Loss:0.0013
# Iteration:38040, Loss:0.0384
# Iteration:38050, Loss:0.0087
# Iteration:38060, Loss:0.0096
# Iteration:38070, Loss:0.0023
# Iteration:38080, Loss:0.0073
# Iteration:38090, Loss:0.0095
# Iteration:38100, Loss:0.0077
# Iteration:38110, Loss:0.0034
# Iteration:38120, Loss:0.0042
# Iteration:38130, Loss:0.0014
# Iteration:38140, Loss:0.0018
# Iteration:38150, Loss:0.0129
# Iteration:38160, Loss:0.0280
# Iteration:38170, Loss:0.0022
# Iteration:38180, Loss:0.0099
# Iteration:38190, Loss:0.0013
# Iteration:38200, Loss:0.0025
# Iteration:38210, Loss:0.0128
# Iteration:38220, Loss:0.0210
# Iteration:38230, Loss:0.0022
# Iteration:38240, Loss:0.0016
# Iteration:38250, Loss:0.0144
# Iteration:38260, Loss:0.0024
# Iteration:38270, Loss:0.0015
# Iteration:38280, Loss:0.0023
# Iteration:38290, Loss:0.0013
# Iteration:38300, Loss:0.0004
# Iteration:38310, Loss:0.0193
# Iteration:38320, Loss:0.0084
# Iteration:38330, Loss:0.0035
# Iteration:38340, Loss:0.0035
# Iteration:38350, Loss:0.0291
# Iteration:38360, Loss:0.0248
# Iteration:38370, Loss:0.0081
# Iteration:38380, Loss:0.0114
# Iteration:38390, Loss:0.0048
# Iteration:38400, Loss:0.0023
# Iteration:38410, Loss:0.0025
# Iteration:38420, Loss:0.0009
# Iteration:38430, Loss:0.0188
# Iteration:38440, Loss:0.0056
# Iteration:38450, Loss:0.0038
# Iteration:38460, Loss:0.0070
# Iteration:38470, Loss:0.0023
# Iteration:38480, Loss:0.0010
# Iteration:38490, Loss:0.0015
# Iteration:38500, Loss:0.0044
# Iteration:38510, Loss:0.0081
# Iteration:38520, Loss:0.0067
# Iteration:38530, Loss:0.0070
# Iteration:38540, Loss:0.0091
# Iteration:38550, Loss:0.0010
# Iteration:38560, Loss:0.0002
# Iteration:38570, Loss:0.0040
# Iteration:38580, Loss:0.0053
# Iteration:38590, Loss:0.0064
# Iteration:38600, Loss:0.0040
# Iteration:38610, Loss:0.0232
# Iteration:38620, Loss:0.0075
# Iteration:38630, Loss:0.0039
# Iteration:38640, Loss:0.0102
# Iteration:38650, Loss:0.0005
# Iteration:38660, Loss:0.0044
# Iteration:38670, Loss:0.0014
# Iteration:38680, Loss:0.0002
# Iteration:38690, Loss:0.0048
# Iteration:38700, Loss:0.0020
# Iteration:38710, Loss:0.0003
# Iteration:38720, Loss:0.0041
# Iteration:38730, Loss:0.0031
# Iteration:38740, Loss:0.0138
# Iteration:38750, Loss:0.0062
# Iteration:38760, Loss:0.0195
# Iteration:38770, Loss:0.0130
# Iteration:38780, Loss:0.0170
# Iteration:38790, Loss:0.0188
# Iteration:38800, Loss:0.0019
# Iteration:38810, Loss:0.0001
# Iteration:38820, Loss:0.0112
# Iteration:38830, Loss:0.0104
# Iteration:38840, Loss:0.0017
# Iteration:38850, Loss:0.0319
# Iteration:38860, Loss:0.0091
# Iteration:38870, Loss:0.0058
# Iteration:38880, Loss:0.0173
# Iteration:38890, Loss:0.0138
# Iteration:38900, Loss:0.0098
# Iteration:38910, Loss:0.0024
# Iteration:38920, Loss:0.0058
# Iteration:38930, Loss:0.0003
# Iteration:38940, Loss:0.0024
# Iteration:38950, Loss:0.0053
# Iteration:38960, Loss:0.0132
# Iteration:38970, Loss:0.0060
# Iteration:38980, Loss:0.0051
# Iteration:38990, Loss:0.0016
# Iteration:39000, Loss:0.0132
# Iteration:39010, Loss:0.0030
# Iteration:39020, Loss:0.0098
# Iteration:39030, Loss:0.0123
# Iteration:39040, Loss:0.0040
# Iteration:39050, Loss:0.0020
# Iteration:39060, Loss:0.0074
# Iteration:39070, Loss:0.0041
# Iteration:39080, Loss:0.0012
# Iteration:39090, Loss:0.0005
# Iteration:39100, Loss:0.0051
# Iteration:39110, Loss:0.0025
# Iteration:39120, Loss:0.0003
# Iteration:39130, Loss:0.0009
# Iteration:39140, Loss:0.0109
# Iteration:39150, Loss:0.0175
# Iteration:39160, Loss:0.0048
# Iteration:39170, Loss:0.0071
# Iteration:39180, Loss:0.0057
# Iteration:39190, Loss:0.0068
# Iteration:39200, Loss:0.0103
# Iteration:39210, Loss:0.0004
# Iteration:39220, Loss:0.0067
# Iteration:39230, Loss:0.0017
# Iteration:39240, Loss:0.0058
# Iteration:39250, Loss:0.0075
# Iteration:39260, Loss:0.0011
# Iteration:39270, Loss:0.0097
# Iteration:39280, Loss:0.0028
# Iteration:39290, Loss:0.0008
# Iteration:39300, Loss:0.0056
# Iteration:39310, Loss:0.0035
# Iteration:39320, Loss:0.0009
# Iteration:39330, Loss:0.0004
# Iteration:39340, Loss:0.0095
# Iteration:39350, Loss:0.0016
# Iteration:39360, Loss:0.0060
# Iteration:39370, Loss:0.0018
# Iteration:39380, Loss:0.0057
# Iteration:39390, Loss:0.0014
# Iteration:39400, Loss:0.0030
# Iteration:39410, Loss:0.0086
# Iteration:39420, Loss:0.0028
# Iteration:39430, Loss:0.0133
# Iteration:39440, Loss:0.0070
# Iteration:39450, Loss:0.0024
# Iteration:39460, Loss:0.0054
# Iteration:39470, Loss:0.0053
# Iteration:39480, Loss:0.0022
# Iteration:39490, Loss:0.0020
# Iteration:39500, Loss:0.0154
# Iteration:39510, Loss:0.0031
# Iteration:39520, Loss:0.0022
# Iteration:39530, Loss:0.0033
# Iteration:39540, Loss:0.0006
# Iteration:39550, Loss:0.0050
# Iteration:39560, Loss:0.0010
# Iteration:39570, Loss:0.0002
# Iteration:39580, Loss:0.0026
# Iteration:39590, Loss:0.0090
# Iteration:39600, Loss:0.0013
# Iteration:39610, Loss:0.0032
# Iteration:39620, Loss:0.0021
# Iteration:39630, Loss:0.0034
# Iteration:39640, Loss:0.0076
# Iteration:39650, Loss:0.0062
# Iteration:39660, Loss:0.0047
# Iteration:39670, Loss:0.0019
# Iteration:39680, Loss:0.0185
# Iteration:39690, Loss:0.0046
# Iteration:39700, Loss:0.0206
# Iteration:39710, Loss:0.0020
# Iteration:39720, Loss:0.0262
# Iteration:39730, Loss:0.0006
# Iteration:39740, Loss:0.0032
# Iteration:39750, Loss:0.0034
# Iteration:39760, Loss:0.0072
# Iteration:39770, Loss:0.0050
# Iteration:39780, Loss:0.0145
# Iteration:39790, Loss:0.0004
# Iteration:39800, Loss:0.0086
# Iteration:39810, Loss:0.0003
# Iteration:39820, Loss:0.0003
# Iteration:39830, Loss:0.0111
# Iteration:39840, Loss:0.0108
# Iteration:39850, Loss:0.0003
# Iteration:39860, Loss:0.0002
# Iteration:39870, Loss:0.0080
# Iteration:39880, Loss:0.0077
# Iteration:39890, Loss:0.0157
# Iteration:39900, Loss:0.0186
# Iteration:39910, Loss:0.0119
# Iteration:39920, Loss:0.0075
# Iteration:39930, Loss:0.0002
# Iteration:39940, Loss:0.0197
# Iteration:39950, Loss:0.0010
# Iteration:39960, Loss:0.0218
# Iteration:39970, Loss:0.0027
# Iteration:39980, Loss:0.0032
# Iteration:39990, Loss:0.0024
# Iteration:40000, Loss:0.0018
# Iteration:40010, Loss:0.0013
# Iteration:40020, Loss:0.0068
# Iteration:40030, Loss:0.0024
# Iteration:40040, Loss:0.0038
# Iteration:40050, Loss:0.0014
# Iteration:40060, Loss:0.0065
# Iteration:40070, Loss:0.0088
# Iteration:40080, Loss:0.0014
# Iteration:40090, Loss:0.0009
# Iteration:40100, Loss:0.0000
# Iteration:40110, Loss:0.0031
# Iteration:40120, Loss:0.0005
# Iteration:40130, Loss:0.0071
# Iteration:40140, Loss:0.0077
# Iteration:40150, Loss:0.0012
# Iteration:40160, Loss:0.0039
# Iteration:40170, Loss:0.0002
# Iteration:40180, Loss:0.0008

# %%
# #Instantiate the class object...
# model = RNNMusicGenerator(4,4)

# #Load in preprocessed sample data
# # data = np.load('nparray_dataset_normalized_small.npy') #Alter to accept the larger dataset...
# data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_medium.pt') #Will take a moment to load...
# #the 'r' in the front is a requirement...
# data = torch.tensor(data).float() #This line prevents an error.

# print(len(data))

# %%
# train_network(model,data,batch_size = 10,num_epochs = 10,learning_rate = 1e-2)

# %% [markdown]
# ## Model Testing

# %% [markdown]
# Since our model is 'tested' with people listening to it, we need to just generate some samples.
# To do so, and because this is a regression style problem, sampling will not be needed. Instead, we will feed it a random set of starting notes from a sample of music.

# %%
#Using random noise inputs:

test_data = torch.load(r'D:\engsci\year 3\CLASS\APS360\Project\data\Notes_Dataset_ws_10_overfit.pt')
test_data = torch.tensor(test_data).float()
test_loader = torch.utils.data.DataLoader(test_data, 
                                           batch_size=1, 
                                           shuffle=True)

for sample in test_loader:
    x = sample # (Batch_size,sequence,notes) --> Must match the model layer input. Want it to give me small positive values!
    break
print('x.shape: ',x.shape)
# print(x)


song_length = 50 #How many new notes we want the model to generate.

start = True
for t in range(0,song_length): #Generates t new notes.
    new_sample,_ = model(x)
#     print(new_sample.shape)
    if start:
#         print(new_sample.shape)
        new_sample = new_sample.unsqueeze(0)
#         print(new_sample.shape)
        new_excerpt = torch.cat((x[:,1:,:],new_sample),1) #initializes new_excerpt as the random noise + new note
        start = False
#         print(new_excerpt.shape)
        x = new_excerpt
#         print(x)
    else:
        new_sample = new_sample.unsqueeze(0)
        new_excerpt = torch.cat((new_excerpt,new_sample),1)
#         print(new_sample.shape)
        x = torch.cat((x[:,1:,:],new_sample),1) #Update x by throwing out the first note in the sequence and shoving the new note to the end.
#         print(x)
        
        
# print(new_excerpt.shape)
print('%% generator loop done %%')
# print(new_excerpt.shape)
# print('new excerpt type: ',type(new_excerpt))
new_excerpt = new_excerpt.detach().numpy()
# new_excerpt = new_excerpt.type(torch.int64)
print('new excerpt: (Watch for the same notes appearing...)',new_excerpt)
new_excerpt = np.array(new_excerpt[0])
print('new_excerpt.shape: ',new_excerpt.shape)

# %%
mid = Numpy2Midi(np.array(new_excerpt),'test_from_model_16_ws20_medium_and_simple_longer')
